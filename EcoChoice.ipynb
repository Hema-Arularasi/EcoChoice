# %%
import requests

class SustainableShoppingApp:
    def __init__(self):
        # Simulated product data stored in a dictionary
        self.product_data = {
            "12345": {"name": "Organic Cotton T-Shirt", "carbon_footprint": 50, "ethical_sourcing": "Yes", "recycling_options": "Yes", "material": "Organic Cotton", "price": 25.99, "description": "A comfortable and sustainable choice for everyday wear.", "alternative": None},
            "67890": {"name": "Bamboo Toothbrush", "carbon_footprint": 30, "ethical_sourcing": "Yes", "recycling_options": "Yes", "material": "Bamboo", "price": 4.99, "description": "An eco-friendly alternative to plastic toothbrushes.", "alternative": None},
            "13579": {"name": "Reusable Water Bottle", "carbon_footprint": 20, "ethical_sourcing": "Yes", "recycling_options": "Yes", "material": "Stainless Steel", "price": 15.99, "description": "Stay hydrated and reduce single-use plastic waste.", "alternative": None},
            "24680": {"name": "Solar-Powered Charger", "carbon_footprint": 10, "ethical_sourcing": "Yes", "recycling_options": "Yes", "material": "Plastic (Recycled)", "price": 29.99, "description": "Charge your devices sustainably with solar power.", "alternative": None},
            "11223": {"name": "Recycled Paper Notebook", "carbon_footprint": 25, "ethical_sourcing": "Yes", "recycling_options": "Yes", "material": "Recycled Paper", "price": 8.99, "description": "Take notes in an environmentally friendly notebook.", "alternative": None},
            "44556": {"name": "Plant-Based Dish Soap", "carbon_footprint": 15, "ethical_sourcing": "Yes", "recycling_options": "Yes", "material": "Plant-Based", "price": 6.99, "description": "Clean dishes without harming the environment.", "alternative": "DIY Dish Soap using natural ingredients."},
            "77889": {"name": "Fair Trade Coffee Beans", "carbon_footprint": 40, "ethical_sourcing": "Yes", "recycling_options": "Yes", "material": "Coffee Beans", "price": 12.99, "description": "Enjoy a cup of coffee with a conscience.", "alternative": "Locally roasted coffee beans."},
            "99011": {"name": "Eco-Friendly Sneakers", "carbon_footprint": 55, "ethical_sourcing": "Yes", "recycling_options": "Yes", "material": "Recycled Materials", "price": 59.99, "description": "Walk sustainably in stylish sneakers.", "alternative": None},
            "22334": {"name": "LED Light Bulbs", "carbon_footprint": 12, "ethical_sourcing": "Yes", "recycling_options": "Yes", "material": "Glass and Metal", "price": 9.99, "description": "Illuminate your space with energy-efficient bulbs.", "alternative": None},
            "55667": {"name": "Upcycled Denim Jeans", "carbon_footprint": 60, "ethical_sourcing": "Yes", "recycling_options": "Yes", "material": "Upcycled Denim", "price": 34.99, "description": "Wear stylish jeans while supporting upcycling.", "alternative": None},
            "88990": {"name": "Biodegradable Phone Case", "carbon_footprint": 18, "ethical_sourcing": "Yes", "recycling_options": "Yes", "material": "Biodegradable Plastic", "price": 14.99, "description": "Protect your phone and the environment with a biodegradable case.", "alternative": None},
            "11223": {"name": "Organic Avocado Oil", "carbon_footprint": 22, "ethical_sourcing": "Yes", "recycling_options": "Yes", "material": "Organic Avocados", "price": 7.99, "description": "Cook with organic avocado oil for a healthier choice.", "alternative": "Use olive oil as an alternative."},
            "33445": {"name": "Sustainable Bamboo Cutlery Set", "carbon_footprint": 28, "ethical_sourcing": "Yes", "recycling_options": "Yes", "material": "Bamboo", "price": 12.99, "description": "Dine sustainably with a bamboo cutlery set.", "alternative": None},
            "55667": {"name": "Cork Yoga Mat", "carbon_footprint": 32, "ethical_sourcing": "Yes", "recycling_options": "Yes", "material": "Cork", "price": 29.99, "description": "Practice yoga on an eco-friendly cork mat.", "alternative": None},
            "77889": {"name": "Fair Trade Chocolate", "carbon_footprint": 45, "ethical_sourcing": "Yes", "recycling_options": "Yes", "material": "Cocoa Beans", "price": 5.99, "description": "Indulge in fair trade chocolate guilt-free.", "alternative": "Make your own chocolate treats using fair trade cocoa powder."},
            "99011": {"name": "Hemp Backpack", "carbon_footprint": 38, "ethical_sourcing": "Yes", "recycling_options": "Yes", "material": "Hemp", "price": 39.99, "description": "Carry your belongings in a durable hemp backpack.", "alternative": None},
            "22334": {"name": "Beeswax Wrap Set", "carbon_footprint": 26, "ethical_sourcing": "Yes", "recycling_options": "Yes", "material": "Beeswax and Cotton", "price": 18.99, "description": "Store food sustainably with beeswax wraps.", "alternative": "Use reusable silicone food wraps."},
            "44556": {"name": "Zero-Waste Shampoo Bar", "carbon_footprint": 17, "ethical_sourcing": "Yes", "recycling_options": "Yes", "material": "Natural Ingredients", "price": 7.99, "description": "Wash your hair without plastic waste.", "alternative": None},
            "66778": {"name": "Sustainably Sourced Salmon", "carbon_footprint": 42, "ethical_sourcing": "Yes", "recycling_options": "Yes", "material": "Salmon", "price": 16.99, "description": "Enjoy sustainably sourced and delicious salmon.", "alternative": None},
            "88990": {"name": "Organic Cotton Bed Sheets", "carbon_footprint": 48, "ethical_sourcing": "Yes", "recycling_options": "Yes", "material": "Organic Cotton", "price": 49.99, "description": "Sleep comfortably with organic cotton bed sheets.", "alternative": None},
        }

    def run_app(self):
        while True:
            # Simulating user entering a product ID
            product_id = input("Enter a product ID (type 'exit' to end): ")
            if product_id.lower() == 'exit':
                print("Exiting Sustainable Shopping App. Goodbye!")
                break
            
            product_info = self.get_product_info(product_id)
            if product_info:
                self.display_product_info(product_info)
            else:
                print("Product not found. Please try again.")
            
            # Ask the user if they want to continue
            continue_input = input("Do you want to scan another product? (yes/no): ")
            if continue_input.lower() != 'yes':
                print("Exiting Sustainable Shopping App. Goodbye!")
                break

    def get_product_info(self, product_id):
        return self.product_data.get(product_id, None)

    def display_product_info(self, product_info):
        print("\nProduct Information:")
        print(f"Name: {product_info['name']}")
        print(f"Carbon Footprint: {product_info['carbon_footprint']} gCO2e")
        print(f"Ethical Sourcing: {product_info['ethical_sourcing']}")
        print(f"Recycling Options: {product_info['recycling_options']}")
        print(f"Material: {product_info['material']}")
        print(f"Price: ${product_info['price']}")
        print(f"Description: {product_info['description']}")
        
        # Check if carbon footprint exceeds the limit
        carbon_footprint_limit = 30  # Set your desired limit here
        if product_info['carbon_footprint'] > carbon_footprint_limit:
            if product_info['alternative']:
                print(f"Sustainable Alternative: {product_info['alternative']}")
            else:
                print("No specific alternative suggested, but consider exploring more sustainable options.")
        
        print("\nMake an eco-friendly choice!")

# Example Usage
if __name__ == "__main__":
    sustainable_app = SustainableShoppingApp()
    sustainable_app.run_app()
# Out:
# Enter a product ID (type 'exit' to end): 44556
#
# Product Information:
# Name: Zero-Waste Shampoo Bar
# Carbon Footprint: 17 gCO2e
# Ethical Sourcing: Yes
# Recycling Options: Yes
# Material: Natural Ingredients
# Price: $7.99
# Description: Wash your hair without plastic waste.
#
# Make an eco-friendly choice!
# Do you want to scan another product? (yes/no): yes
# Enter a product ID (type 'exit' to end): 88990
#
# Product Information:
# Name: Organic Cotton Bed Sheets
# Carbon Footprint: 48 gCO2e
# Ethical Sourcing: Yes
# Recycling Options: Yes
# Material: Organic Cotton
# Price: $49.99
# Description: Sleep comfortably with organic cotton bed sheets.
# No specific alternative suggested, but consider exploring more sustainable options.
#
# Make an eco-friendly choice!
# Do you want to scan another product? (yes/no): no
# Exiting Sustainable Shopping App. Goodbye!
